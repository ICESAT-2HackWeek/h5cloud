# %%
from h5cloud.test_config import TestConfig
from h5cloud.tests.h5py_arr_mean import H5pyArrMean

# %%
tc = TestConfig.load_from_yaml(yaml_file="h5cloud/file_configs/atl03.yml", results_bucket="eodc-scratch", results_directory="h5cloud-tests/test-results")

# %%
h5py_arr_test = H5pyArrMean(tc)

# %%
og_result = h5py_arr_test.run('original')

# %%
repacked_result = h5py_arr_test.run('repack_page_4gb')

# %%
og_result
# Out:
# (210.20262049342506, 4.287616014480591)

# %%
repacked_result
# Out:
# (210.20262049342506, 0.8477990627288818)
